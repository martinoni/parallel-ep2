# %% [markdown]
# # EP1 de Programacao Paralela e distribuida - MAC5742
# ## Analise dos Resultados

# %% [markdown]
# | Nome | NUSP |
# |------|------|
# | Ariel Serranoni Soares da Silva| 7658024 |
# | Thiago Martinoni | 9793401 |

# %% [markdown]
# ### Resumo
# Em Topologia, um conjunto é auto
# A implementação sequencial  é muito comum em disciplinas introdutórias de computação. Neste trabalho vamos além, implementaremos três versões deste algorítmo, a clássica sequencial, uma utilizando pthreads e uma terceira utilizando open mp. Os códigos em C e seus encontram-se disponíveis em bla. Aqui vamos analisar o desempenho de cada algorítmo afim de obter um parâmetro de comparação a respeito do
# desempenho dessas bibliotecas.
#
# ### Implementações em C
#
# Temos três arquivos, cada um responsável por calcular o conjunto de mandelbrot utilizando um método diferente.
# O Programa mandelbrot_seq serve como base para os outros dois.
# Notando que cada iteração do loop exterior na função compute_mandelbrot é responsável por produzir uma linha completa da imagem
# final e que cada linha é independente. adotamos isso como unidade elementar e distribuímos o trabalho entre múltiplas threads
#
# Nas implementações em paralelo, utilizamos a estratégia de divisão estática
# tanto no programa mandelbrot_pth quanto no mandelbrot_omp afim de obter uma comparação mais justa possível. Por isso deixamos todas as varíavei
#
# Quando o usuário solicita um número maior de threads do que de linhas na imagem
# Medições de tempo e output usamos do EP anterior.

# %% [markdown]
# ### Infra estrutura Julia
#
# Para este relatório, usamos jupyter notebooks e Julia, conforme nos eps anteriores. Também usamos os mesmos pacotes e muitas das funções do nosso último trabalho adaptadas ao novo problema. A seguinte célula fará as instalações de pacotes julia

# %%
]up
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
#   Updating `~/ariel-ep1-paralela/src/Project.toml`
#  [no changes]
#   Updating `~/ariel-ep1-paralela/src/Manifest.toml`
#  [no changes]

# %%
using Pkg 
Pkg.build("FFTW")
# Out:
#   Building FFTW → `~/.julia/packages/FFTW/5DZuu/deps/build.log`
# false

# %%
] st
# Out:
#     Status `~/ariel-ep1-paralela/src/Project.toml`
#   [336ed68f] CSV v0.6.2
#   [a93c6f00] DataFrames v0.21.1
#   [31c24e10] Distributions v0.23.3
#   [7073ff75] IJulia v1.21.2
#   [8314cec4] PGFPlotsX v1.2.6
#   [1a8c2f83] Query v0.12.2
#   [f3b207a7] StatsPlots v0.14.6

# %% [markdown]
# ### Experimentos
#
# O Primeiro passo para analisarmos o tempo de execução de um determinado programa sempre foi e sempre será executar o programa
# em questão. A função abaixo é uma adaptação da função `blá`, do mini EP3. Seu objetivo é justamente fazer uma chamada na linha de comando e salvar alguns dados.
#
# Os parâmetros envolvidos nos experimentos são:
#
# | Parâmetro | Valores  |
# |------|------|
# |   I/O e Aloc. Mem  | Sem; Com e Sem |
# |   № de Threads  | $2^0$, ... $2^5$ |
# |   Tamanho da Entrada   | $2^4$, ... $2^{13}$ |
# |   № de Execuções   | 10 |

# %%
using DataFrames, Query, StatsPlots, Statistics

function mandelbrot(method, region, image_size, threads=1)
    a=region[2][1]
    b=region[2][2]
    c=region[2][3]
    d=region[2][4]
    results = parse.(Float64,
        split(chomp(read(`./mandelbrot_$method $a  $b $c $d $image_size $threads`, String)), ", "))
        
    return DataFrame(size = image_size,
                region=region[1],
                delta_x = region[2][2] - region[2][1],
                delta_y = region[2][4] - region[2][3],
                duration_clock = results[1],
                duration_mono = results[2],
                duration_sys = results[3],
                threads=threads,
                method=method)
    end
# Out:
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1273
# mandelbrot (generic function with 2 methods)

# %% [markdown]
# Para que nossa análise tenha alguma significância do ponto de vista estatístico, precisamos nos basear em um número arbitrário, mas suficiente, de execuções do programa. A função a seguir, também adaptada do miniEP3 tem o intuito de automatizar
# repetidas chamadas dos programas em C, feitas pela função acima, coletar os resultados e retorná-los na forma de um DataFrame.

# %%
function run_experiments(methods, regions ,image_size, threads, repetitions)
    run(`make`)
    
    results = DataFrame(size = Int64[],
                region = String[],
                delta_x = Float64[],
                delta_y = Float64[],
                duration_clock = Float64[],
                duration_mono = Float64[],
                duration_sys = Float64[],
                threads= Int64[],
                method= String[])
    
    for tuple in regions
        for method in methods
            for size in image_size
                for t in 1:length(threads)
                    if (threads[t] <= 1 || method != "seq") 
                        for r in 1:repetitions
                            append!(results, mandelbrot(method, tuple, size, threads[t]))
                
                        end
                    end
                end
            end
        end
    end
    return results
end
# Out:
# run_experiments (generic function with 1 method)

# %%
function parse_results(results)
  parsed_results=results|>
                @groupby((_.threads,_.method,_.region)) |>
                @map({threads_method = key(_),
                repetitions=repetitions,
                size = mean(_.size),
                delta_x = mean(_.delta_x),
                delta_y = mean(_.delta_y),
                mean_duration_clock = mean(_.duration_clock),
                mean_duration_mono = mean(_.duration_mono),
                mean_duration_sys = mean(_.duration_sys),
                ci_duration_clock = 1.96 * std(_.duration_clock),
                ci_duration_mono = 1.96 * std(_.duration_mono),
                ci_duration_sys = 1.96 * std(_.duration_sys)})|>
                DataFrame
    
      final_results = DataFrame(threads= Int64[],
                    method= String[],
                    region = String[],
                    size = Int64[],
                    delta_x = Float64[],
                    delta_y = Float64[],
                    mean_duration_clock = Float64[],
                    mean_duration_mono = Float64[],
                    mean_duration_sys = Float64[],
                    ci_duration_clock = Float64[],
                    ci_duration_mono = Float64[],
                    ci_duration_sys = Float64[],
                    repetitions = Int64[])
    
        for i in 1:length(parsed_results.size)
            
            append!(final_results, DataFrame(size=parsed_results.size[i],
                                        delta_x=parsed_results.delta_x[i],
                                         delta_y=parsed_results.delta_y[i],
                                        mean_duration_clock=parsed_results.mean_duration_clock[i],
                                        mean_duration_mono=parsed_results.mean_duration_mono[i],
                                        mean_duration_sys=parsed_results.mean_duration_sys[i],
                                        ci_duration_clock=parsed_results.ci_duration_clock[i],
                                        ci_duration_mono=parsed_results.ci_duration_mono[i],
                                        ci_duration_sys=parsed_results.ci_duration_sys[i],
                                        repetitions =parsed_results.repetitions[i],
                                        threads = parsed_results.threads_method[i][1],
                                        method = parsed_results.threads_method[i][2],
                                        region = parsed_results.threads_method[i][3]))
    
        end
    return final_results
end
# Out:
# parse_results (generic function with 1 method)

# %% [markdown]
# Antes de iniciar os experimentos, vamos ajustar os parâmetros para que os experimentos ocorram como proposto no enunciado

# %%
sizes=[2^x for x in 4:5]
threads = [2 ^ x for x in 0:3]
methods = ["seq","pth","omp"]

regions = Dict("Full Picture" => (-2.5,1.5,-2.0,2.0),
                "Seahorse Valley" => (-0.8,-0.7,0.05,0.15),
                "Elephant Valley" => (0.175,0.375,-0.1,0.1),
                "Triple Spiral Valley" =>(-0.188,-0.012,0.554,0.754))
repetitions=10
results = run_experiments(methods, regions, sizes, threads, repetitions)
parsed_results = parse_results(results)
# Out:
# make: Nothing to be done for 'all'.
# 36×13 DataFrame. Omitted printing of 7 columns
# │ Row │ threads │ method │ region               │ size  │ delta_x │ delta_y │
# │     │ Int64   │ String │ String               │ Int64 │ Float64 │ Float64 │
# ├─────┼─────────┼────────┼──────────────────────┼───────┼─────────┼─────────┤
# │ 1   │ 1       │ seq    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 2   │ 1       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 3   │ 2       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 4   │ 4       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 5   │ 8       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 6   │ 1       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 7   │ 2       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 8   │ 4       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 9   │ 8       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 10  │ 1       │ seq    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# ⋮
# │ 26  │ 4       │ omp    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 27  │ 8       │ omp    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 28  │ 1       │ seq    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 29  │ 1       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 30  │ 2       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 31  │ 4       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 32  │ 8       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 33  │ 1       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 34  │ 2       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 35  │ 4       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 36  │ 8       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │

# %% [markdown]
# Como a função run_experiments pode fazer muitas chamadas dos programas em C, salvar os resultados em um arquivo pode ser uma forma de agilizar o fluxo de trabalho. No nosso caso, precisamos executar 1200 chamadas na linha de comando. Isso torna essencial o armazenamento dos resultados em disco. As seguintes funções são reaproveitadas do miniEP3 e nos ajudam com esse trabalho.

# %%
using CSV

function save_csv_results(data_frame)
    CSV.write("./data_frame.csv",data_frame,delim='\t')
end

function read_csv_results()
    df=CSV.read("./data_frame.csv")
    return df
end

# save_csv_results(parsed_results)
# Out:
# read_csv_results (generic function with 1 method)

# %%
# parsed_results = read_csv_results()
showall(parsed_results)
# Out:
# ┌ Warning: `showall(df::AbstractDataFrame, allcols::Bool=true)` is deprecated, use `show(df, allrows=true, allcols=allcols)` instead.
# │   caller = showall(::DataFrame) at deprecated.jl:66
# └ @ DataFrames ./deprecated.jl:66
# 36×13 DataFrame
# │ Row │ threads │ method │ region               │ size  │ delta_x │ delta_y │
# │     │ Int64   │ String │ String               │ Int64 │ Float64 │ Float64 │
# ├─────┼─────────┼────────┼──────────────────────┼───────┼─────────┼─────────┤
# │ 1   │ 1       │ seq    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 2   │ 1       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 3   │ 2       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 4   │ 4       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 5   │ 8       │ pth    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 6   │ 1       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 7   │ 2       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 8   │ 4       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 9   │ 8       │ omp    │ Full Picture         │ 24    │ 4.0     │ 4.0     │
# │ 10  │ 1       │ seq    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 11  │ 1       │ pth    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 12  │ 2       │ pth    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 13  │ 4       │ pth    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 14  │ 8       │ pth    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 15  │ 1       │ omp    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 16  │ 2       │ omp    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 17  │ 4       │ omp    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 18  │ 8       │ omp    │ Seahorse Valley      │ 24    │ 0.1     │ 0.1     │
# │ 19  │ 1       │ seq    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 20  │ 1       │ pth    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 21  │ 2       │ pth    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 22  │ 4       │ pth    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 23  │ 8       │ pth    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 24  │ 1       │ omp    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 25  │ 2       │ omp    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 26  │ 4       │ omp    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 27  │ 8       │ omp    │ Elephant Valley      │ 24    │ 0.2     │ 0.2     │
# │ 28  │ 1       │ seq    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 29  │ 1       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 30  │ 2       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 31  │ 4       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 32  │ 8       │ pth    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 33  │ 1       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 34  │ 2       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 35  │ 4       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
# │ 36  │ 8       │ omp    │ Triple Spiral Valley │ 24    │ 0.176   │ 0.2     │
#
# │ Row │ mean_duration_clock │ mean_duration_mono │ mean_duration_sys │
# │     │ Float64             │ Float64            │ Float64           │
# ├─────┼─────────────────────┼────────────────────┼───────────────────┤
# │ 1   │ 0.0002328           │ 0.000219           │ 0.0002168         │
# │ 2   │ 0.00049505          │ 0.0114477          │ 0.0114461         │
# │ 3   │ 0.00067565          │ 0.013375           │ 0.0133734         │
# │ 4   │ 0.00098345          │ 0.0153915          │ 0.0153902         │
# │ 5   │ 0.0017768           │ 0.0183063          │ 0.0183047         │
# │ 6   │ 0.00024715          │ 0.00023605         │ 0.0002345         │
# │ 7   │ 0.004377            │ 0.0109714          │ 0.01097           │
# │ 8   │ 0.00929015          │ 0.0139534          │ 0.0139516         │
# │ 9   │ 0.0203416           │ 0.0182639          │ 0.0182624         │
# │ 10  │ 0.00131395          │ 0.00131735         │ 0.0013155         │
# │ 11  │ 0.0015304           │ 0.0107448          │ 0.0107431         │
# │ 12  │ 0.0016687           │ 0.0130485          │ 0.0130473         │
# │ 13  │ 0.001884            │ 0.0156341          │ 0.0156326         │
# │ 14  │ 0.00287505          │ 0.0218228          │ 0.0218213         │
# │ 15  │ 0.00137005          │ 0.00136055         │ 0.0013587         │
# │ 16  │ 0.0054129           │ 0.0119865          │ 0.0119851         │
# │ 17  │ 0.00928715          │ 0.0150478          │ 0.0150463         │
# │ 18  │ 0.0246373           │ 0.0226102          │ 0.0226086         │
# │ 19  │ 0.0012643           │ 0.00125445         │ 0.0012529         │
# │ 20  │ 0.0015168           │ 0.0107462          │ 0.0107447         │
# │ 21  │ 0.00165565          │ 0.0130252          │ 0.0130239         │
# │ 22  │ 0.0019644           │ 0.0155923          │ 0.0155904         │
# │ 23  │ 0.0025073           │ 0.0208469          │ 0.0208455         │
# │ 24  │ 0.0012803           │ 0.0012693          │ 0.00126765        │
# │ 25  │ 0.00528095          │ 0.0121068          │ 0.0121054         │
# │ 26  │ 0.009279            │ 0.0156716          │ 0.01567           │
# │ 27  │ 0.0213271           │ 0.0216443          │ 0.0216429         │
# │ 28  │ 0.00147035          │ 0.00146025         │ 0.00145885        │
# │ 29  │ 0.00174975          │ 0.0108254          │ 0.0108239         │
# │ 30  │ 0.0018849           │ 0.0115683          │ 0.0115669         │
# │ 31  │ 0.0020752           │ 0.0150033          │ 0.0150017         │
# │ 32  │ 0.0027117           │ 0.0197766          │ 0.0197752         │
# │ 33  │ 0.00149505          │ 0.00168475         │ 0.0016831         │
# │ 34  │ 0.0055804           │ 0.0114956          │ 0.0114943         │
# │ 35  │ 0.009875            │ 0.0143694          │ 0.0143678         │
# │ 36  │ 0.0250935           │ 0.0226704          │ 0.022669          │
#
# │ Row │ ci_duration_clock │ ci_duration_mono │ ci_duration_sys │ repetitions │
# │     │ Float64           │ Float64          │ Float64         │ Int64       │
# ├─────┼───────────────────┼──────────────────┼─────────────────┼─────────────┤
# │ 1   │ 0.000244807       │ 0.000245846      │ 0.000245463     │ 10          │
# │ 2   │ 0.000261376       │ 0.00287285       │ 0.00287265      │ 10          │
# │ 3   │ 0.00040826        │ 0.00370627       │ 0.0037058       │ 10          │
# │ 4   │ 0.000294585       │ 0.00386922       │ 0.00386901      │ 10          │
# │ 5   │ 0.000605079       │ 0.0120952        │ 0.0120955       │ 10          │
# │ 6   │ 0.000254994       │ 0.000255179      │ 0.000254663     │ 10          │
# │ 7   │ 0.00100173        │ 0.00352576       │ 0.00352598      │ 10          │
# │ 8   │ 0.00294219        │ 0.0039016        │ 0.00390172      │ 10          │
# │ 9   │ 0.0121157         │ 0.00492923       │ 0.00492964      │ 10          │
# │ 10  │ 0.00157514        │ 0.00156584       │ 0.00156554      │ 10          │
# │ 11  │ 0.00149565        │ 0.00220313       │ 0.00220349      │ 10          │
# │ 12  │ 0.00151605        │ 0.00519438       │ 0.00519443      │ 10          │
# │ 13  │ 0.00145556        │ 0.00466826       │ 0.0046682       │ 10          │
# │ 14  │ 0.00232971        │ 0.0118538        │ 0.0118539       │ 10          │
# │ 15  │ 0.00152858        │ 0.00153101       │ 0.00153125      │ 10          │
# │ 16  │ 0.00172294        │ 0.00385285       │ 0.00385278      │ 10          │
# │ 17  │ 0.00148191        │ 0.00298084       │ 0.00298094      │ 10          │
# │ 18  │ 0.0176909         │ 0.00658252       │ 0.00658264      │ 10          │
# │ 19  │ 0.00151717        │ 0.0015183        │ 0.00151781      │ 10          │
# │ 20  │ 0.0015539         │ 0.00250292       │ 0.00250293      │ 10          │
# │ 21  │ 0.00142535        │ 0.00724388       │ 0.00724412      │ 10          │
# │ 22  │ 0.0014343         │ 0.00551455       │ 0.00551432      │ 10          │
# │ 23  │ 0.00131118        │ 0.00629965       │ 0.00629956      │ 10          │
# │ 24  │ 0.00148206        │ 0.00148405       │ 0.00148436      │ 10          │
# │ 25  │ 0.00139369        │ 0.00330548       │ 0.00330479      │ 10          │
# │ 26  │ 0.00151404        │ 0.0032845        │ 0.00328479      │ 10          │
# │ 27  │ 0.0117658         │ 0.00462678       │ 0.0046273       │ 10          │
# │ 28  │ 0.00174859        │ 0.00175204       │ 0.00175183      │ 10          │
# │ 29  │ 0.00181118        │ 0.0023444        │ 0.00234409      │ 10          │
# │ 30  │ 0.00183262        │ 0.00311353       │ 0.00311338      │ 10          │
# │ 31  │ 0.00168596        │ 0.00410352       │ 0.00410345      │ 10          │
# │ 32  │ 0.00170893        │ 0.0102291        │ 0.0102292       │ 10          │
# │ 33  │ 0.00173247        │ 0.00273722       │ 0.00273693      │ 10          │
# │ 34  │ 0.00227145        │ 0.00380717       │ 0.00380751      │ 10          │
# │ 35  │ 0.00306535        │ 0.00355144       │ 0.00355176      │ 10          │
# │ 36  │ 0.0170739         │ 0.00694718       │ 0.00694699      │ 10          │

# %%
pgfplotsx()

function plot_results(x, y, group, target_label, series_label; hline = [], yerror = [], max_thread_power = 10)
    if yerror != []
        p = groupedbar(x,
            y,
            bar_position  = :dodge,
#             xaxis = :log2,
            group=group,
            xlabel = "Threads",
#             xticks = [2 ^ x for x in 0:max_thread_power],
            yerror = yerror,
            alpha = 100,
            labels = series_label,
            legend = :topright)
    else
        p = scatter(x,
            y,
            xaxis = :log2,
            group=group,
            xlabel = "Threads",
            xticks = [2 ^ x for x in 0:max_thread_power],
            alpha = 0.6,
            labels = series_label,
            legend = :topright)
    end

    if hline != []
        plot!(x,
            hline,
            xaxis = :log2,
            xlabel = "Threads",
            xticks = [2 ^ x for x in 0:max_thread_power],
            labels = target_label,
            line = :dash,
            width = 2.0)
    end

    return p
end
data_full_picture = parsed_results[parsed_results.region .== "Full Picture",:]
data_seahorse_valley = parsed_results[parsed_results.region .== "Seahorse Valley",:]
# Out:
# 9×13 DataFrame. Omitted printing of 7 columns
# │ Row │ threads │ method │ region          │ size  │ delta_x │ delta_y │
# │     │ Int64   │ String │ String          │ Int64 │ Float64 │ Float64 │
# ├─────┼─────────┼────────┼─────────────────┼───────┼─────────┼─────────┤
# │ 1   │ 1       │ seq    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 2   │ 1       │ pth    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 3   │ 2       │ pth    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 4   │ 4       │ pth    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 5   │ 8       │ pth    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 6   │ 1       │ omp    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 7   │ 2       │ omp    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 8   │ 4       │ omp    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │
# │ 9   │ 8       │ omp    │ Seahorse Valley │ 24    │ 0.1     │ 0.1     │

# %%
p1=plot_results(string.(data_full_picture.threads),
            data_full_picture.mean_duration_mono,
            data_full_picture.method,
            "",
            yerror = data_full_picture.ci_duration_mono, 
            data_full_picture.method,
            max_thread_power = 10)

p2=plot_results(string.(data_seahorse_valley.threads),
            data_seahorse_valley.mean_duration_mono,
            data_seahorse_valley.method,
            "",
            yerror = data_seahorse_valley.ci_duration_mono, 
            data_seahorse_valley.method,
            max_thread_power = 10)

plot(p1,p2, layout=(1,2), title = "Qualquer coisa" , legend=true)

# %%
string.(data_full_picture.threads)
# Out:
# 9-element Array{String,1}:
#  "1"
#  "1"
#  "2"
#  "4"
#  "8"
#  "1"
#  "2"
#  "4"
#  "8"
